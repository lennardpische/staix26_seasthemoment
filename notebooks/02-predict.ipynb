# %% [markdown]
# # STAI-X 2026: Final Submission (Award A)

# %%
import subprocess, sys

kaggle = False
try:
    from pathlib import Path
    if Path('/kaggle/input/staix-challenge').exists():
        kaggle = True
except:
    pass

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))
from pathlib import Path
from src.predict import run
from src.data_loader import find_data_dir

# Get data root and output directory
root   = Path('/kaggle/input/staix-challenge') if kaggle else find_data_dir()
output_path = Path('/kaggle/working/submission.csv') if kaggle else Path('../submission.csv')
submission = run(root = root, output_path = output_path)
